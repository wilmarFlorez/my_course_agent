# %%
import os
import sys

sys.path.insert(0, os.path.abspath(".."))

# %%
from IPython.display import Image, display

from src.agents.main import agent

display(Image(agent.get_graph().draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 from IPython.display import Image, display
#       2
# ----> 3 from src.agents.main import agent
#       4
#       5 display(Image(agent.get_graph().draw_mermaid_png()))
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/src/agents/main.py:10
#       6     """Get weather for a given city."""
#       7     return f"It's always sunny in {city}!"
# ---> 10 agent = create_agent(
#      11     model="openai:gpt-5.4-mini",
#      12     tools=[get_weather],
#      13     system_prompt="You are a helpful assistant",
#      14 )
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:839, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache)
#     837 # init chat model
#     838 if isinstance(model, str):
# --> 839     model = init_chat_model(model)
#     841 # Convert system_prompt to SystemMessage if needed
#     842 system_message: SystemMessage | None = None
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:479, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     471     warnings.warn(
#     472         f"{config_prefix=} has been set but no fields are configurable. Set "
#     473         f"`configurable_fields=(...)` to specify the model params that are "
#     474         f"configurable.",
#     475         stacklevel=2,
#     476     )
#     478 if not configurable_fields:
# --> 479     return _init_chat_model_helper(
#     480         cast("str", model),
#     481         model_provider=model_provider,
#     482         **kwargs,
#     483     )
#     484 if model:
#     485     kwargs["model"] = model
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:503, in _init_chat_model_helper(model, model_provider, **kwargs)
#     501 model, model_provider = _parse_model(model, model_provider)
#     502 creator_func = _get_chat_model_creator(model_provider)
# --> 503 return creator_func(model=model, **kwargs)
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:35, in _call(cls, **kwargs)
#      33 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      34     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 35     return cls(**kwargs)
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/.venv/lib/python3.13/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1253, in BaseChatOpenAI.validate_environment(self)
#    1239         self.http_async_client = _build_proxied_async_httpx_client(
#    1240             proxy=self.openai_proxy,
#    1241             verify=global_ssl_context,
#    1242             socket_options=resolved_socket_options,
#    1243         )
#    1244     async_specific = {
#    1245         "http_client": self.http_async_client
#    1246         or _get_default_async_httpx_client(
#    (...)   1251         "api_key": async_api_key_value,
#    1252     }
# -> 1253     self.root_async_client = openai.AsyncOpenAI(
#    1254         **client_params,
#    1255         **async_specific,  # type: ignore[arg-type]
#    1256     )
#    1257     self.async_client = self.root_async_client.chat.completions
#    1258 return self
#
# File ~/Documentos/learn/langchain/platzi/my_course_agent/.venv/lib/python3.13/site-packages/openai/_client.py:587, in AsyncOpenAI.__init__(self, api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     585     api_key = os.environ.get("OPENAI_API_KEY")
#     586 if api_key is None:
# --> 587     raise OpenAIError(
#     588         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     589     )
#     590 if callable(api_key):
#     591     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
print(agent.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	model(model)
# 	tools(tools)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> model;
# 	model -.-> __end__;
# 	model -.-> tools;
# 	tools -.-> model;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
